# %%
import torch
import torch.nn as nn
import torchvision
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
# from model import *
import time


# 1、加载数据
train_data = torchvision.datasets.CIFAR10(root="./dataset/torch_data", train=True, transform=torchvision.transforms.ToTensor(),
                                            download=True)  
test_data = torchvision.datasets.CIFAR10(root="./dataset/torch_data", train=False, transform=torchvision.transforms.ToTensor(),
                                            download=True)

# 2、得到length 长度
train_data_size = len(train_data)
test_data_size = len(test_data)
print("训练集的长度为:{}".format(train_data_size))
print("测试集的长度为:{}".format(test_data_size))

# 3、利用dataloaders来加载数据
train_data_loader = DataLoader(train_data, batch_size=64)
test_data_loader = DataLoader(test_data, batch_size=64)

# 4、创建网络模型
class Tudui(nn.Module):
    def __init__(self):
        super(Tudui, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 32, 5, 1, 2), # 3是输入的通道数，32是输出的通道数，5是卷积核的大小，1是步长，2是padding
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(32, 32, 5, 1, 2),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(32, 64, 5, 1, 2),
            nn.MaxPool2d(kernel_size=2),
            nn.Flatten(),
            nn.Linear(64*4*4, 64),
            nn.Linear(64, 10)
        )
        
    def forward(self, x):
        x = self.model(x)
        return x
    
    
tudui = Tudui()
if torch.cuda.is_available():
    tudui = tudui.cuda()
    print("GPU可用")

# 5、定义损失函数
loss_function = nn.CrossEntropyLoss()
if torch.cuda.is_available():
    loss_function = loss_function.cuda()

# 6、定义优化器
# 1e-2 = 1 * 10 ^ (-2) = 0.01
learning_rate = 1e-2
optimizer = torch.optim.SGD(tudui.parameters(), lr=learning_rate)

# 7、设置训练网络的一些参数
total_train_step = 0
# 记录测试的次数
total_test_step = 0
# 训练的轮数
epoch = 20

#8、添加tensorboard
writer = SummaryWriter("./logs")

for i in range(epoch):
    print("--------第{}轮训练开始------------".format(i+1))
    for data in train_data_loader:
        start_time = time.time()
        imgs, targets = data
        if torch.cuda.is_available():
            imgs = imgs.cuda()
            targets = targets.cuda()
        outputs = tudui(imgs)
        loss = loss_function(outputs, targets)
        
        # 优化器调优模型
        # 梯度清零
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        total_train_step += 1
        if total_train_step % 100 == 0:
            end_time = time.time()
            #输出运行时间
            print("训练100次所用时间为:{}".format(end_time - start_time))
            print("训练次数：{}, Loss:{}".format(total_train_step, loss.item()))
            writer.add_scalar("train_loss", loss.item(), total_train_step)
            
    #测试步骤
    total_test_loss = 0
    total_accuracy = 0
    with torch.no_grad():
        for data in test_data_loader:
            imgs, targets = data
            if torch.cuda.is_available():
                imgs = imgs.cuda()
                targets = targets.cuda()
            outputs = tudui(imgs)
            loss = loss_function(outputs, targets)
            total_test_loss += loss.item()
            accuracy = (outputs.argmax(1) == targets).sum()
            total_accuracy = accuracy + total_accuracy
            
    print("整体测试集上的Loss为:{}".format(total_test_loss))
    print("整体测试集上的正确率为:{}".format(total_accuracy / test_data_size))
    writer.add_scalar("test_loss", total_test_loss, total_test_step)
    writer.add_scalar("test_accuracy", total_accuracy / test_data_size, total_test_step)
    total_test_step += 1
    
    torch.save(tudui, "tudui_{}.pth".format(i))
    print("模型已保存")
    
writer.close()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 训练集的长度为:50000
# 测试集的长度为:10000
# GPU可用
# --------第1轮训练开始------------
# 训练100次所用时间为:0.0039043426513671875
# 训练次数：100, Loss:2.2945473194122314
# 训练100次所用时间为:0.0039010047912597656
# 训练次数：200, Loss:2.2890377044677734
# 训练100次所用时间为:0.004906892776489258
# 训练次数：300, Loss:2.273952007293701
# 训练100次所用时间为:0.0039014816284179688
# 训练次数：400, Loss:2.2014474868774414
# 训练100次所用时间为:0.003902912139892578
# 训练次数：500, Loss:2.1529643535614014
# 训练100次所用时间为:0.004873752593994141
# 训练次数：600, Loss:2.056563377380371
# 训练100次所用时间为:0.0039250850677490234
# 训练次数：700, Loss:2.0034778118133545
# 整体测试集上的Loss为:311.447655916214
# 整体测试集上的正确率为:0.28619998693466187
# 模型已保存
# --------第2轮训练开始------------
# 训练100次所用时间为:0.003904104232788086
# 训练次数：800, Loss:1.8873709440231323
# 训练100次所用时间为:0.003900289535522461
# 训练次数：900, Loss:1.8353476524353027
# 训练100次所用时间为:0.0039446353912353516
# 训练次数：1000, Loss:1.9434629678726196
# 训练100次所用时间为:0.002933025360107422
# 训练次数：1100, Loss:1.9806571006774902
# 训练100次所用时间为:0.004898786544799805
# 训练次数：1200, Loss:1.719906210899353
# 训练100次所用时间为:0.003931522369384766
# 训练次数：1300, Loss:1.6513307094573975
# 训练100次所用时间为:0.003907203674316406
# 训练次数：1400, Loss:1.7466977834701538
# 训练100次所用时间为:0.003902912139892578
# 训练次数：1500, Loss:1.8067920207977295
# 整体测试集上的Loss为:306.1450515985489
# 整体测试集上的正确率为:0.3141999840736389
# 模型已保存
# --------第3轮训练开始------------
# 训练100次所用时间为:0.003903627395629883
# 训练次数：1600, Loss:1.713629961013794
# 训练100次所用时间为:0.003900289535522461
# 训练次数：1700, Loss:1.6151899099349976
# 训练100次所用时间为:0.00391387939453125
# 训练次数：1800, Loss:1.8857958316802979
# 训练100次所用时间为:0.003930807113647461
# 训练次数：1900, Loss:1.6780674457550049
# 训练100次所用时间为:0.0039052963256835938
# 训练次数：2000, Loss:1.9058876037597656
# 训练100次所用时间为:0.004873514175415039
# 训练次数：2100, Loss:1.5042036771774292
# 训练100次所用时间为:0.003928422927856445
# 训练次数：2200, Loss:1.435082197189331
# 训练100次所用时间为:0.0029265880584716797
# 训练次数：2300, Loss:1.7406114339828491
# 整体测试集上的Loss为:265.8634897470474
# 整体测试集上的正确率为:0.3904999792575836
# 模型已保存
# --------第4轮训练开始------------
# 训练100次所用时间为:0.0039017200469970703
# 训练次数：2400, Loss:1.6858634948730469
# 训练100次所用时间为:0.0039026737213134766
# 训练次数：2500, Loss:1.3165922164916992
# 训练100次所用时间为:0.003897428512573242
# 训练次数：2600, Loss:1.6505664587020874
# 训练100次所用时间为:0.0039014816284179688
# 训练次数：2700, Loss:1.633689045906067
# 训练100次所用时间为:0.003908634185791016
# 训练次数：2800, Loss:1.4883991479873657
# 训练100次所用时间为:0.0039000511169433594
# 训练次数：2900, Loss:1.598960041999817
# 训练100次所用时间为:0.003900766372680664
# 训练次数：3000, Loss:1.3612651824951172
# 训练100次所用时间为:0.004902839660644531
# 训练次数：3100, Loss:1.541696310043335
# 整体测试集上的Loss为:254.10313284397125
# 整体测试集上的正确率为:0.4138999879360199
# 模型已保存
# --------第5轮训练开始------------
# 训练100次所用时间为:0.003911018371582031
# 训练次数：3200, Loss:1.320137619972229
# 训练100次所用时间为:0.0029273033142089844
# 训练次数：3300, Loss:1.4441943168640137
# 训练100次所用时间为:0.0039014816284179688
# 训练次数：3400, Loss:1.3841633796691895
# 训练100次所用时间为:0.0048792362213134766
# 训练次数：3500, Loss:1.5385541915893555
# 训练100次所用时间为:0.003929853439331055
# 训练次数：3600, Loss:1.4946820735931396
# 训练100次所用时间为:0.003901958465576172
# 训练次数：3700, Loss:1.3719693422317505
# 训练100次所用时间为:0.002927064895629883
# 训练次数：3800, Loss:1.263425350189209
# 训练100次所用时间为:0.003932952880859375
# 训练次数：3900, Loss:1.4206172227859497
# 整体测试集上的Loss为:243.76620185375214
# 整体测试集上的正确率为:0.44099998474121094
# 模型已保存
# --------第6轮训练开始------------
# 训练100次所用时间为:0.003930091857910156
# 训练次数：4000, Loss:1.4057791233062744
# 训练100次所用时间为:0.003896951675415039
# 训练次数：4100, Loss:1.3964091539382935
# 训练100次所用时间为:0.0029265880584716797
# 训练次数：4200, Loss:1.5499776601791382
# 训练100次所用时间为:0.0038971900939941406
# 训练次数：4300, Loss:1.1838245391845703
# 训练100次所用时间为:0.0048828125
# 训练次数：4400, Loss:1.0971351861953735
# 训练100次所用时间为:0.002926349639892578
# 训练次数：4500, Loss:1.3066288232803345
# 训练100次所用时间为:0.003892183303833008
# 训练次数：4600, Loss:1.3965901136398315
# 整体测试集上的Loss为:230.12149310112
# 整体测试集上的正确率为:0.4702000021934509
# 模型已保存
# --------第7轮训练开始------------
# 训练100次所用时间为:0.003930568695068359
# 训练次数：4700, Loss:1.3450409173965454
# 训练100次所用时间为:0.003899812698364258
# 训练次数：4800, Loss:1.4535126686096191
# 训练100次所用时间为:0.003905057907104492
# 训练次数：4900, Loss:1.3687995672225952
# 训练100次所用时间为:0.002925872802734375
# 训练次数：5000, Loss:1.384852409362793
# 训练100次所用时间为:0.0038743019104003906
# 训练次数：5100, Loss:0.9955909252166748
# 训练100次所用时间为:0.002958059310913086
# 训练次数：5200, Loss:1.3459500074386597
# 训练100次所用时间为:0.003933906555175781
# 训练次数：5300, Loss:1.1376368999481201
# 训练100次所用时间为:0.004877805709838867
# 训练次数：5400, Loss:1.366733431816101
# 整体测试集上的Loss为:217.7560636997223
# 整体测试集上的正确率为:0.5019999742507935
# 模型已保存
# --------第8轮训练开始------------
# 训练100次所用时间为:0.003904104232788086
# 训练次数：5500, Loss:1.1607131958007812
# 训练100次所用时间为:0.003912925720214844
# 训练次数：5600, Loss:1.1622806787490845
# 训练100次所用时间为:0.0039005279541015625
# 训练次数：5700, Loss:1.186423420906067
# 训练100次所用时间为:0.0039021968841552734
# 训练次数：5800, Loss:1.1564081907272339
# 训练100次所用时间为:0.0029511451721191406
# 训练次数：5900, Loss:1.343280553817749
# 训练100次所用时间为:0.004906654357910156
# 训练次数：6000, Loss:1.4949448108673096
# 训练100次所用时间为:0.0039021968841552734
# 训练次数：6100, Loss:1.0721875429153442
# 训练100次所用时间为:0.003930330276489258
# 训练次数：6200, Loss:1.0871148109436035
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
